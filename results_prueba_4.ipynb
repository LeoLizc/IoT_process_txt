# %% [markdown]
# # Análisis de Resultados: Pruebas de Transmisión SDR: Prueba 4

# %% [markdown]
# ### Importación de Módulos

# %%
from src.data_processes import load_csv, limpiar_datos, extraer_distancia
from src.data_analyses import stats_paquetes, describir_metricas, comparar_metricas_por_distancia
from src.data_visualizations import plot_histograma, plot_correlacion, plot_metricas_por_distancia
import pandas as pd

# %% [markdown]
# ### Procesamiento de Datos

# %% [markdown]
# #### Carga de Datos

# %%
#1 metro
df_2M1M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "1m-2MSPs-7sf-125khz-1", muestras=2)
df_4M1M_S12_500K = load_csv("data/prueba_4/26-06-2025_csv/", "1m-4MSPs-12sf-500khz-1", muestras=4)
df_8M1M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "1m-8MSPs-7sf-125khz-1", muestras=8)

#30 metros
df_2M30M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "30m-2MSPs-7sf-125khz-1", muestras=2)
df_4M30M_S12_500K = load_csv("data/prueba_4/26-06-2025_csv/", "30m-4MSPs-12sf-500khz-1", muestras=4)
df_8M30M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "30m-8MSPs-7sf-125khz-1", muestras=8)

#60 metros
df_2M60M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "60m-2MSPs-7sf-125khz-1", muestras=2)
df_4M60M_S12_500K = load_csv("data/prueba_4/26-06-2025_csv/", "60m-4MSPs-12sf-500khz-1", muestras=4)
df_8M60M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "60m-8MSPs-7sf-125khz-1", muestras=8)

#120 metros
df_2M120M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "120m-2MSPs-7sf-125khz-1", muestras=2)
df_4M120M_S12_500K = load_csv("data/prueba_4/26-06-2025_csv/", "120m-4MSPs-12sf-500khz-1", muestras=4)
df_8M120M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "120m-8MSPs-7sf-125khz-1", muestras=8)

#180 metros
df_2M180M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "180m-2MSPs-7sf-125khz-1", muestras=2)
df_4M180M_S12_500K = load_csv("data/prueba_4/26-06-2025_csv/", "180m-4MSPs-12sf-500khz-1", muestras=4)
df_8M180M_SF7_125K = load_csv("data/prueba_4/26-06-2025_csv/", "180m-8MSPs-7sf-125khz-1", muestras=8)

# %% [markdown]
# #### Cantidad de Paquetes y Errores

# %% [markdown]
# 1 Metro

# %%
display(stats_paquetes(df_2M1M_SF7_125K))
display(stats_paquetes(df_4M1M_S12_500K))
display(stats_paquetes(df_8M1M_SF7_125K))
# Out:
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               104          104             0           0             0
#
#    porcentaje_rx_ok
# 0             100.0
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               104          104             0           0             0
#
#    porcentaje_rx_ok
# 0             100.0
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               105          102             3           3            39
#
#    porcentaje_rx_ok
# 0         97.142857

# %% [markdown]
# 30 Metros

# %%
display(stats_paquetes(df_2M30M_SF7_125K))
display(stats_paquetes(df_4M30M_S12_500K))
display(stats_paquetes(df_8M30M_SF7_125K))
# Out:
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               103          103             0           0             0
#
#    porcentaje_rx_ok
# 0             100.0
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               104          104             0           0             0
#
#    porcentaje_rx_ok
# 0             100.0
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               104          104             0           0            23
#
#    porcentaje_rx_ok
# 0             100.0

# %% [markdown]
# 60 Metros

# %%
display(stats_paquetes(df_2M60M_SF7_125K))
display(stats_paquetes(df_4M60M_S12_500K))
display(stats_paquetes(df_8M60M_SF7_125K))
# Out:
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               106          106             0           0             0
#
#    porcentaje_rx_ok
# 0             100.0
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               107          106             1           1             0
#
#    porcentaje_rx_ok
# 0         99.065421
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               107          107             0           0            25
#
#    porcentaje_rx_ok
# 0             100.0

# %% [markdown]
# 120 Metros

# %%
display(stats_paquetes(df_2M120M_SF7_125K))
display(stats_paquetes(df_4M120M_S12_500K))
display(stats_paquetes(df_8M120M_SF7_125K))
# Out:
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0                99           99             0           0             0
#
#    porcentaje_rx_ok
# 0             100.0
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               105          105             0           0             1
#
#    porcentaje_rx_ok
# 0             100.0
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               110          110             0           0             7
#
#    porcentaje_rx_ok
# 0             100.0

# %% [markdown]
# 180 Metros

# %%
display(stats_paquetes(df_2M180M_SF7_125K))
display(stats_paquetes(df_4M180M_S12_500K))
display(stats_paquetes(df_8M180M_SF7_125K))
# Out:
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               107          107             0           0             0
#
#    porcentaje_rx_ok
# 0             100.0
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               106          105             1           1             2
#
#    porcentaje_rx_ok
# 0         99.056604
#    paquetes_totales  paquetes_ok  paquetes_err  crc_errors  overflow_sum  \
# 0               109          109             0           0            10
#
#    porcentaje_rx_ok
# 0             100.0

# %% [markdown]
# #### Análisis Estadístico de los Paquetes

# %% [markdown]
# 60 Metros

# %%
display(describir_metricas(df_2M1M_SF7_125K))
display(describir_metricas(df_4M1M_S12_500K))
display(describir_metricas(df_8M1M_SF7_125K))
# Out:
#            numero  my_sto         sto         cfo         snr  crc_error  \
# count  104.000000     0.0  104.000000  104.000000  104.000000      104.0
# mean    51.500000     NaN   58.885976   -0.224224   11.140045        0.0
# std     30.166206     NaN   37.339212    0.168629    0.761996        0.0
# min      0.000000     NaN    0.722372   -1.199750    8.476810        0.0
# 25%     25.750000     NaN   25.274600   -0.200022   10.772225        0.0
# 50%     51.500000     NaN   57.954050   -0.195914   11.223250        0.0
# 75%     77.250000     NaN   94.315800   -0.190795   11.561500        0.0
# max    103.000000     NaN  126.304000   -0.183728   13.047800        0.0
#
#        previous_overflow_sum       k_hat       k_hat2    espacios    cfo_int2  \
# count                  104.0  104.000000   104.000000  104.000000  104.000000
# mean                     0.0   58.884615  1021.519231   63.394231  575.490385
# ...

# %% [markdown]
# 30 Metros

# %%
display(describir_metricas(df_2M30M_SF7_125K))
display(describir_metricas(df_4M30M_S12_500K))
display(describir_metricas(df_8M30M_SF7_125K))
# Out:
#            numero  my_sto         sto         cfo         snr  crc_error  \
# count  103.000000     0.0  103.000000  103.000000  103.000000      103.0
# mean    51.000000     NaN   63.628130   -0.256374   10.962351        0.0
# std     29.877528     NaN   43.136966    0.269114    1.758910        0.0
# min      0.000000     NaN    0.830766   -1.192310    6.098460        0.0
# 25%     25.500000     NaN   21.497350   -0.184741    9.594915        0.0
# 50%     51.000000     NaN   65.698000   -0.179494   10.605800        0.0
# 75%     76.500000     NaN  104.716000   -0.175010   12.481800        0.0
# max    102.000000     NaN  126.871000   -0.162123   14.270900        0.0
#
#        previous_overflow_sum       k_hat       k_hat2    espacios    cfo_int2  \
# count                  103.0  103.000000   103.000000  103.000000  103.000000
# mean                     0.0   63.572816   963.941748   59.796117  575.174757
# ...

# %% [markdown]
# 60 Metros

# %%
display(describir_metricas(df_2M60M_SF7_125K))
display(describir_metricas(df_4M60M_S12_500K))
display(describir_metricas(df_8M60M_SF7_125K))
# Out:
#            numero  my_sto         sto         cfo         snr  crc_error  \
# count  106.000000     0.0  106.000000  106.000000  106.000000      106.0
# mean    52.500000     NaN   61.836081   -0.272204   10.365563        0.0
# std     30.743563     NaN   37.556173    0.282253    2.365590        0.0
# min      0.000000     NaN   -0.169851   -1.212660    4.130750        0.0
# 25%     26.250000     NaN   26.885000   -0.194849    8.838045        0.0
# 50%     52.500000     NaN   66.000050   -0.187754   10.414200        0.0
# 75%     78.750000     NaN   96.096250   -0.182210   11.890200        0.0
# max    105.000000     NaN  126.533000   -0.160301   15.022800        0.0
#
#        previous_overflow_sum       k_hat       k_hat2    espacios    cfo_int2  \
# count                  106.0  106.000000   106.000000  106.000000  106.000000
# mean                     0.0   61.820755  1082.396226   67.141509  576.094340
# ...

# %% [markdown]
# 120 Metros

# %%
display(describir_metricas(df_2M120M_SF7_125K))
display(describir_metricas(df_4M120M_S12_500K))
display(describir_metricas(df_8M120M_SF7_125K))
# Out:
#            numero  my_sto         sto        cfo        snr  crc_error  \
# count   99.000000     0.0   99.000000  99.000000  99.000000       99.0
# mean    50.101010     NaN   68.722740  -0.231926   7.345035        0.0
# std     29.354795     NaN   38.213128   0.222224   3.486341        0.0
# min      0.000000     NaN    0.736339  -1.194060  -3.771880        0.0
# 25%     25.500000     NaN   33.129600  -0.188623   5.389100        0.0
# 50%     50.000000     NaN   79.654300  -0.182362   8.649410        0.0
# 75%     75.500000     NaN  100.821500  -0.175677  10.008435        0.0
# max    100.000000     NaN  127.606000  -0.100726  11.507600        0.0
#
#        previous_overflow_sum       k_hat       k_hat2    espacios    cfo_int2  \
# count                   99.0   99.000000    99.000000   99.000000   99.000000
# mean                     0.0   68.676768  1052.686869   65.343434  574.878788
# std                      0.0   38.264074   505.817113   31.568249   11.121108
# ...

# %% [markdown]
# 180 Metros

# %%
display(describir_metricas(df_2M180M_SF7_125K))
display(describir_metricas(df_4M180M_S12_500K))
display(describir_metricas(df_8M180M_SF7_125K))
# Out:
#            numero  my_sto         sto         cfo         snr  crc_error  \
# count  107.000000     0.0  107.000000  107.000000  107.000000      107.0
# mean    53.000000     NaN   57.525001   -0.260404    8.448370        0.0
# std     31.032241     NaN   36.091966    0.232449    2.121352        0.0
# min      0.000000     NaN    0.093355   -1.220040    0.433913        0.0
# 25%     26.500000     NaN   26.205050   -0.211230    8.377405        0.0
# 50%     53.000000     NaN   50.466200   -0.205640    9.239910        0.0
# 75%     79.500000     NaN   92.131600   -0.199208    9.726425        0.0
# max    106.000000     NaN  125.374000   -0.150674   10.721300        0.0
#
#        previous_overflow_sum       k_hat       k_hat2    espacios    cfo_int2  \
# count                  107.0  107.000000   107.000000  107.000000  107.000000
# mean                     0.0   57.467290  1008.654206   62.598131  574.102804
# ...

# %% [markdown]
# ### Visualización de Resultados

# %% [markdown]
# 1 Metro

# %%
plot_histograma(df_2M1M_SF7_125K, output_path="output/prueba_4/2mm1m_sf7_125k/histograma/")
plot_correlacion(df_2M1M_SF7_125K, output_path="output/prueba_4/2mm1m_sf7_125k/correlacion/")

plot_histograma(df_4M1M_S12_500K, output_path="output/prueba_4/4mm1m_s12_500k/histograma/")
plot_correlacion(df_4M1M_S12_500K, output_path="output/prueba_4/4mm1m_s12_500k/correlacion/")

plot_histograma(df_8M1M_SF7_125K, output_path="output/prueba_4/8mm1m_sf7_125k/histograma/")
plot_correlacion(df_8M1M_SF7_125K, output_path="output/prueba_4/8mm1m_sf7_125k/correlacion/")

# %% [markdown]
# 30 Metros

# %%
plot_histograma(df_2M30M_SF7_125K, output_path="output/prueba_4/2mm30m_sf7_125k/histograma/")
plot_correlacion(df_2M30M_SF7_125K, output_path="output/prueba_4/2mm30m_sf7_125k/correlacion/")
plot_histograma(df_4M30M_S12_500K, output_path="output/prueba_4/4mm30m_s12_500k/histograma/")
plot_correlacion(df_4M30M_S12_500K, output_path="output/prueba_4/4mm30m_s12_500k/correlacion/")
plot_histograma(df_8M30M_SF7_125K, output_path="output/prueba_4/8mm30m_sf7_125k/histograma/")
plot_correlacion(df_8M30M_SF7_125K, output_path="output/prueba_4/8mm30m_sf7_125k/correlacion/")

# %% [markdown]
# 60 Metros

# %%
plot_histograma(df_2M60M_SF7_125K, output_path="output/prueba_4/2mm60m_sf7_125k/histograma/")
plot_correlacion(df_2M60M_SF7_125K, output_path="output/prueba_4/2mm60m_sf7_125k/correlacion/")
plot_histograma(df_4M60M_S12_500K, output_path="output/prueba_4/4mm60m_s12_500k/histograma/")
plot_correlacion(df_4M60M_S12_500K, output_path="output/prueba_4/4mm60m_s12_500k/correlacion/")
plot_histograma(df_8M60M_SF7_125K, output_path="output/prueba_4/8mm60m_sf7_125k/histograma/")
plot_correlacion(df_8M60M_SF7_125K, output_path="output/prueba_4/8mm60m_sf7_125k/correlacion/")

# %% [markdown]
# 120 Metros

# %%
plot_histograma(df_2M120M_SF7_125K, output_path="output/prueba_4/2mm120m_sf7_125k/histograma/")
plot_correlacion(df_2M120M_SF7_125K, output_path="output/prueba_4/2mm120m_sf7_125k/correlacion/")
plot_histograma(df_4M120M_S12_500K, output_path="output/prueba_4/4mm120m_s12_500k/histograma/")
plot_correlacion(df_4M120M_S12_500K, output_path="output/prueba_4/4mm120m_s12_500k/correlacion/")
plot_histograma(df_8M120M_SF7_125K, output_path="output/prueba_4/8mm120m_sf7_125k/histograma/")
plot_correlacion(df_8M120M_SF7_125K, output_path="output/prueba_4/8mm120m_sf7_125k/correlacion/")

# %% [markdown]
# 180 Metros

# %%
plot_histograma(df_2M180M_SF7_125K, output_path="output/prueba_4/2mm180m_sf7_125k/histograma/")
plot_correlacion(df_2M180M_SF7_125K, output_path="output/prueba_4/2mm180m_sf7_125k/correlacion/")
plot_histograma(df_4M180M_S12_500K, output_path="output/prueba_4/4mm180m_s12_500k/histograma/")
plot_correlacion(df_4M180M_S12_500K, output_path="output/prueba_4/4mm180m_s12_500k/correlacion/")
plot_histograma(df_8M180M_SF7_125K, output_path="output/prueba_4/8mm180m_sf7_125k/histograma/")
plot_correlacion(df_8M180M_SF7_125K, output_path="output/prueba_4/8mm180m_sf7_125k/correlacion/")

# %% [markdown]
# 120 Metros

# %% [markdown]
# # Estadísticas de Resultados

# %% [markdown]
# El propósito de este análisis es demostrar si estas se encuentran afectadas significativamente por la distancia o no. Las variables relevantes en el dataset para determinar esta relación son `my_sto`, `sto`, `snr` y `cfo`. El entorno de pruebas fue dividido en dos datasets. Uno con los datos a 4Mbps y otro a 8Mbps, con la columna `distancia` como el valor sobre el que se hará la agrupación.
#
# Se realizaron pruebas Shapiro-Wilk para comprobar normalidad junto con Levene para comprobar su homocedasticidad. Para el dataset de 8Mpbs, `snr` y `cfo` presentaron varianzas desiguales con normalidad, por lo que se aplicó Anova Welch [1]. El resto de datos no cumplieron ninguno de estos supuestos; Anova y Anova Welch fueron descartados para ellos. Por ende, se optó por utilizar Kruskal-Wallis, adecuada para datos desbalanceados y con distribución no normal [2].

# %% [markdown]
# [1] Laerd Statistics, One-way ANOVA using SPSS Statistics. [Online]. Available: https://statistics.laerd.com/spss-tutorials/one-way-anova-using-spss-statistics.php.
#
# [2] J. H. McDonald, Handbook of Biological Statistics, 3rd ed. Baltimore, MD: Sparky House Publishing, 2014. [Online]. Available: http://www.biostathandbook.com/kruskalwallis.html

# %% [markdown]
# ### Pruebas de Normalidad y Homocedasticidad

# %%
metricas = ['sto', 'snr', 'cfo', 'k_hat', 'k_hat2', 'espacios', 'cfo_int2', 'sto_estimate2','muestras', 'muestras_2']
resultados_2M_ = []
resultados_4M_ = []
resultados_8M_ = []

# %%
df_completo_8M_ = pd.concat([df_8M1M_SF7_125K, df_8M30M_SF7_125K, df_8M60M_SF7_125K, df_8M120M_SF7_125K, df_8M180M_SF7_125K], ignore_index=True)

# %%
df_completo_2M_ = pd.concat([df_2M1M_SF7_125K, df_2M30M_SF7_125K, df_2M60M_SF7_125K, df_2M120M_SF7_125K, df_2M180M_SF7_125K], ignore_index=True)
df_completo_2M_['distancia'] = df_completo_2M_['prueba'].apply(extraer_distancia)
df_completo_2M_['distancia'] = df_completo_2M_['distancia'].astype(float)
df_completo_2M_['sf'] = 'SF7'

df_completo_4M_ = pd.concat([df_4M1M_S12_500K, df_4M30M_S12_500K, df_4M60M_S12_500K, df_4M120M_S12_500K, df_4M180M_S12_500K], ignore_index=True)
df_completo_4M_['distancia'] = df_completo_4M_['prueba'].apply(extraer_distancia)
df_completo_4M_['distancia'] = df_completo_4M_['distancia'].astype(float)
df_completo_4M_['sf'] = 'SF12'

df_completo_8M_ = pd.concat([df_8M1M_SF7_125K, df_8M30M_SF7_125K, df_8M60M_SF7_125K, df_8M120M_SF7_125K, df_8M180M_SF7_125K], ignore_index=True)
df_completo_8M_['distancia'] = df_completo_8M_['prueba'].apply(extraer_distancia)
df_completo_8M_['distancia'] = df_completo_8M_['distancia'].astype(float)
df_completo_8M_['sf'] = 'SF7'

# %% [markdown]
# 2MM

# %%
for metrica in metricas:
    if metrica in df_completo_2M_.columns:
        resultado = comparar_metricas_por_distancia(df_completo_2M_, metrica, columna_grupo='distancia')
        resultados_2M_.append(resultado)
        
pd.DataFrame(resultados_2M_)
# Out:
#          metrica            test       p-valor
# 0            sto  Kruskal-Wallis  2.853478e-01
# 1            snr  Kruskal-Wallis  1.395796e-40
# 2            cfo  Kruskal-Wallis  5.356862e-48
# 3          k_hat  Kruskal-Wallis  2.869615e-01
# 4         k_hat2  Kruskal-Wallis  5.163027e-01
# 5       espacios  Kruskal-Wallis  5.340055e-01
# 6       cfo_int2  Kruskal-Wallis  3.061639e-01
# 7  sto_estimate2  Kruskal-Wallis  5.238349e-01
# 8       muestras  Kruskal-Wallis  2.853478e-01
# 9     muestras_2  Kruskal-Wallis  2.905648e-01

# %% [markdown]
# 4MM

# %%
for metrica in metricas:
    if metrica in df_completo_4M_.columns:
        resultado = comparar_metricas_por_distancia(df_completo_4M_, metrica, columna_grupo='distancia')
        resultados_4M_.append(resultado)
pd.DataFrame(resultados_4M_)
# Out:
#          metrica            test       p-valor
# 0            sto  Kruskal-Wallis  3.998246e-03
# 1            snr  Kruskal-Wallis  4.507503e-57
# 2            cfo  Kruskal-Wallis  3.700849e-13
# 3          k_hat  Kruskal-Wallis  3.951979e-03
# 4         k_hat2  Kruskal-Wallis  8.718214e-01
# 5       espacios  Kruskal-Wallis  8.707919e-01
# 6       cfo_int2  Kruskal-Wallis  5.085059e-33
# 7  sto_estimate2  Kruskal-Wallis  1.682820e-02
# 8       muestras  Kruskal-Wallis  3.998246e-03
# 9     muestras_2  Kruskal-Wallis  3.958825e-03

# %% [markdown]
# 8MM

# %%
for metrica in metricas:
    if metrica in df_completo_8M_.columns:
        resultado = comparar_metricas_por_distancia(df_completo_8M_, metrica, columna_grupo='distancia')
        resultados_8M_.append(resultado)
pd.DataFrame(resultados_8M_)
# Out:
#          metrica            test       p-valor
# 0            sto  Kruskal-Wallis  8.888850e-02
# 1            snr  Kruskal-Wallis  1.708090e-66
# 2            cfo  Kruskal-Wallis  4.333633e-39
# 3          k_hat  Kruskal-Wallis  8.748520e-02
# 4         k_hat2  Kruskal-Wallis  9.534206e-01
# 5       espacios  Kruskal-Wallis  9.501782e-01
# 6       cfo_int2  Kruskal-Wallis  3.477548e-01
# 7  sto_estimate2  Kruskal-Wallis  9.564953e-01
# 8       muestras  Kruskal-Wallis  8.888850e-02
# 9     muestras_2  Kruskal-Wallis  8.752775e-02

# %%
plot_metricas_por_distancia(df_completo_2M_, metricas, tipo='box', columna_grupo='distancia', output_path="output/prueba_4/metricas_por_distancia_2mm/")
plot_metricas_por_distancia(df_completo_4M_, metricas, tipo='box', columna_grupo='distancia', output_path="output/prueba_4/metricas_por_distancia_4mm/")
plot_metricas_por_distancia(df_completo_8M_, metricas, tipo='box', columna_grupo='distancia', output_path="output/prueba_4/metricas_por_distancia_8mm/")
